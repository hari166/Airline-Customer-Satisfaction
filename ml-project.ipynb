# %% [markdown]
# # Airline Customer Satisfaction
# #

# %% [markdown]
# **Submitted By :**
#
# *  K. Gopikrishna - AM.EN.U4CSE20033
# *  Harichand Manoj - AM.EN.U4CSE20029
# *  K Udaya Sankar - AM.EN.U4CSE20038
# *  Aadith Anil Kumar - AM.EN.U4CSE20001
# *  Sidharth PV - AM.EN.U4CSE20066

# %% [markdown]
# # Import libraries and Dataset

# %% [markdown]
# Includes Phase 1 and 2

# %%
# importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
# importing dataset
dataset = pd.read_csv("/kaggle/input/invistico-airline/Invistico_Airline.csv")

# %% [markdown]
# # Step 1: Descriptive Statistics

# %%
# Preview data
dataset.head()
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied    Male  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Female  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# 0               0  ...               2                       3
# 1               0  ...               2                       3
# 2               0  ...               2                       2
# 3               0  ...               3                       1
# 4               0  ...               4                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 3                 0                 3                5
# 1                 4                 4                 4                2
# 2                 3                 3                 4                4
# 3                 1                 0                 1                4
# 4                 2                 0                 2                4
#
#    Cleanliness  Online boarding  Departure Delay in Minutes  \
# 0            3                2                           0
# 1            3                2                         310
# 2            4                2                           0
# 3            1                3                           0
# 4            2                5                           0
#
#    Arrival Delay in Minutes
# 0                       0.0
# 1                     305.0
# 2                       0.0
# 3                       0.0
# 4                       0.0
#
# [5 rows x 23 columns]

# %%
# Dataset dimensions - (rows, columns)
dataset.shape
# Out:
# (129880, 23)

# %%
dataset['satisfaction'].value_counts()
# Out:
# satisfied       71087
# dissatisfied    58793
# Name: satisfaction, dtype: int64

# %%
dataset.groupby('satisfaction').mean()
# Out:
#                     Age  Flight Distance  Seat comfort  \
# satisfaction
# dissatisfied  37.466671      2025.709234      2.467335
# satisfied     41.050051      1944.770281      3.145653
#
#               Departure/Arrival time convenient  Food and drink  \
# satisfaction
# dissatisfied                           3.016686        2.660419
# satisfied                              2.969108        3.010438
#
#               Gate location  Inflight wifi service  Inflight entertainment  \
# satisfaction
# dissatisfied       3.007756               2.919854                2.608644
# satisfied          2.976086               3.521460                4.024308
#
#               Online support  Ease of Online booking  On-board service  \
# satisfaction
# dissatisfied        2.959213                2.852261          2.973126
# satisfied           3.983260                3.984751          3.871946
#
#               Leg room service  Baggage handling  Checkin service  \
# satisfaction
# dissatisfied          3.052625          3.364601         2.971850
# satisfied             3.844247          3.969488         3.645955
#
#               Cleanliness  Online boarding  Departure Delay in Minutes  \
# satisfaction
# dissatisfied     3.377324         2.869695                   17.807749
# satisfied        3.977394         3.751966                   12.154768
#
#               Arrival Delay in Minutes
# satisfaction
# dissatisfied                 18.504599
# satisfied                    12.268883

# %%
# separating the data and labels
X = dataset.drop(columns = 'satisfaction',axis =1)
Y = dataset['satisfaction']

# %%
print(X)
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0       Female     Loyal Customer   65  Personal Travel       Eco
# 1         Male     Loyal Customer   47  Personal Travel  Business
# 2       Female     Loyal Customer   15  Personal Travel       Eco
# 3       Female     Loyal Customer   60  Personal Travel       Eco
# 4       Female     Loyal Customer   70  Personal Travel       Eco
# ...        ...                ...  ...              ...       ...
# 129875  Female  disloyal Customer   29  Personal Travel       Eco
# 129876    Male  disloyal Customer   63  Personal Travel  Business
# 129877    Male  disloyal Customer   69  Personal Travel       Eco
# 129878    Male  disloyal Customer   66  Personal Travel       Eco
# 129879  Female  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0                   265             0                                  0
# 1                  2464             0                                  0
# 2                  2138             0                                  0
# 3                   623             0                                  0
# 4                   354             0                                  0
# ...                 ...           ...                                ...
# 129875             1731             5                                  5
# 129876             2087             2                                  3
# 129877             2320             3                                  0
# 129878             2450             3                                  2
# 129879             4307             3                                  4
#
#         Food and drink  Gate location  ...  Online support  \
# 0                    0              2  ...               2
# 1                    0              3  ...               2
# 2                    0              3  ...               2
# 3                    0              3  ...               3
# 4                    0              3  ...               4
# ...                ...            ...  ...             ...
# 129875               5              3  ...               2
# 129876               2              4  ...               1
# 129877               3              3  ...               2
# 129878               3              2  ...               2
# 129879               3              3  ...               3
#
#         Ease of Online booking  On-board service  Leg room service  \
# 0                            3                 3                 0
# 1                            3                 4                 4
# 2                            2                 3                 3
# 3                            1                 1                 0
# 4                            2                 2                 0
# ...                        ...               ...               ...
# 129875                       2                 3                 3
# 129876                       3                 2                 3
# 129877                       4                 4                 3
# 129878                       3                 3                 2
# 129879                       4                 5                 5
#
#         Baggage handling  Checkin service  Cleanliness  Online boarding  \
# 0                      3                5            3                2
# 1                      4                2            3                2
# 2                      4                4            4                2
# 3                      1                4            1                3
# 4                      2                4            2                5
# ...                  ...              ...          ...              ...
# 129875                 4                4            4                2
# 129876                 3                1            2                1
# 129877                 4                2            3                2
# 129878                 3                2            1                2
# 129879                 5                3            3                3
#
#         Departure Delay in Minutes  Arrival Delay in Minutes
# 0                                0                       0.0
# 1                              310                     305.0
# 2                                0                       0.0
# 3                                0                       0.0
# 4                                0                       0.0
# ...                            ...                       ...
# 129875                           0                       0.0
# 129876                         174                     172.0
# 129877                         155                     163.0
# 129878                         193                     205.0
# 129879                         185                     186.0
#
# [129880 rows x 22 columns]

# %%
print(Y)
# Out:
# 0            satisfied
# 1            satisfied
# 2            satisfied
# 3            satisfied
# 4            satisfied
#               ...
# 129875       satisfied
# 129876    dissatisfied
# 129877    dissatisfied
# 129878    dissatisfied
# 129879    dissatisfied
# Name: satisfaction, Length: 129880, dtype: object

# %%
# Features data-type
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Seat comfort                       129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
#  11  Inflight wifi service              129880 non-null  int64
#  12  Inflight entertainment             129880 non-null  int64
#  13  Online support                     129880 non-null  int64
#  14  Ease of Online booking             129880 non-null  int64
#  15  On-board service                   129880 non-null  int64
#  16  Leg room service                   129880 non-null  int64
#  17  Baggage handling                   129880 non-null  int64
#  18  Checkin service                    129880 non-null  int64
#  19  Cleanliness                        129880 non-null  int64
#  20  Online boarding                    129880 non-null  int64
#  21  Departure Delay in Minutes         129880 non-null  int64
#  22  Arrival Delay in Minutes           129487 non-null  float64
# dtypes: float64(1), int64(17), object(5)
# memory usage: 22.8+ MB

# %%
# Statistical summary
dataset.describe().T
# Out:
#                                       count         mean          std   min  \
# Age                                129880.0    39.427957    15.119360   7.0
# Flight Distance                    129880.0  1981.409055  1027.115606  50.0
# Seat comfort                       129880.0     2.838597     1.392983   0.0
# Departure/Arrival time convenient  129880.0     2.990645     1.527224   0.0
# Food and drink                     129880.0     2.851994     1.443729   0.0
# Gate location                      129880.0     2.990422     1.305970   0.0
# Inflight wifi service              129880.0     3.249130     1.318818   0.0
# Inflight entertainment             129880.0     3.383477     1.346059   0.0
# Online support                     129880.0     3.519703     1.306511   0.0
# Ease of Online booking             129880.0     3.472105     1.305560   0.0
# On-board service                   129880.0     3.465075     1.270836   0.0
# Leg room service                   129880.0     3.485902     1.292226   0.0
# Baggage handling                   129880.0     3.695673     1.156483   1.0
# Checkin service                    129880.0     3.340807     1.260582   0.0
# Cleanliness                        129880.0     3.705759     1.151774   0.0
# Online boarding                    129880.0     3.352587     1.298715   0.0
# Departure Delay in Minutes         129880.0    14.713713    38.071126   0.0
# Arrival Delay in Minutes           129487.0    15.091129    38.465650   0.0
#
#                                       25%     50%     75%     max
# Age                                  27.0    40.0    51.0    85.0
# Flight Distance                    1359.0  1925.0  2544.0  6951.0
# Seat comfort                          2.0     3.0     4.0     5.0
# Departure/Arrival time convenient     2.0     3.0     4.0     5.0
# Food and drink                        2.0     3.0     4.0     5.0
# Gate location                         2.0     3.0     4.0     5.0
# Inflight wifi service                 2.0     3.0     4.0     5.0
# Inflight entertainment                2.0     4.0     4.0     5.0
# Online support                        3.0     4.0     5.0     5.0
# Ease of Online booking                2.0     4.0     5.0     5.0
# On-board service                      3.0     4.0     4.0     5.0
# Leg room service                      2.0     4.0     5.0     5.0
# Baggage handling                      3.0     4.0     5.0     5.0
# Checkin service                       3.0     3.0     4.0     5.0
# Cleanliness                           3.0     4.0     5.0     5.0
# Online boarding                       2.0     4.0     4.0     5.0
# Departure Delay in Minutes            0.0     0.0    12.0  1592.0
# Arrival Delay in Minutes              0.0     0.0    13.0  1584.0

# %%
# Count of null values
dataset.isnull().sum()
# Out:
# satisfaction                           0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %% [markdown]
# # Observations:
#
# 1)There are a total of 129880 records and 22 features in the dataset.
# 2)Each feature can be either of integer or float or object dataype.
# 3)Some features like Cleanliness,Flight Distance etc have zero values which represent missing data.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# **Cleaning Data**

# %%
dataset=dataset.drop(['Gender','Age','Type of Travel','Gate location','Online boarding'],axis=1)

# %% [markdown]
# **Converting satisfaction from string to int**

# %% [markdown]
# In the Satisfaction column, now 1 represents satisfied and 0 represents dissatisfied.

# %%
map = {'satisfied':1, 'dissatisfied':0}
dataset.applymap(lambda s: map.get(s) if s in map else s)
# Out:
#         satisfaction      Customer Type     Class  Flight Distance  \
# 0                  1     Loyal Customer       Eco              265
# 1                  1     Loyal Customer  Business             2464
# 2                  1     Loyal Customer       Eco             2138
# 3                  1     Loyal Customer       Eco              623
# 4                  1     Loyal Customer       Eco              354
# ...              ...                ...       ...              ...
# 129875             1  disloyal Customer       Eco             1731
# 129876             0  disloyal Customer  Business             2087
# 129877             0  disloyal Customer       Eco             2320
# 129878             0  disloyal Customer       Eco             2450
# 129879             0  disloyal Customer       Eco             4307
#
#         Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0                  0                                  0               0
# 1                  0                                  0               0
# 2                  0                                  0               0
# 3                  0                                  0               0
# 4                  0                                  0               0
# ...              ...                                ...             ...
# 129875             5                                  5               5
# 129876             2                                  3               2
# 129877             3                                  0               3
# 129878             3                                  2               3
# 129879             3                                  4               3
#
#         Inflight wifi service  Inflight entertainment  Online support  \
# 0                           2                       4               2
# 1                           0                       2               2
# 2                           2                       0               2
# 3                           3                       4               3
# 4                           4                       3               4
# ...                       ...                     ...             ...
# 129875                      2                       5               2
# 129876                      2                       1               1
# 129877                      3                       2               2
# 129878                      3                       2               2
# 129879                      3                       3               3
#
#         Ease of Online booking  On-board service  Leg room service  \
# 0                            3                 3                 0
# 1                            3                 4                 4
# 2                            2                 3                 3
# 3                            1                 1                 0
# 4                            2                 2                 0
# ...                        ...               ...               ...
# 129875                       2                 3                 3
# 129876                       3                 2                 3
# 129877                       4                 4                 3
# 129878                       3                 3                 2
# 129879                       4                 5                 5
#
#         Baggage handling  Checkin service  Cleanliness  \
# 0                      3                5            3
# 1                      4                2            3
# 2                      4                4            4
# 3                      1                4            1
# 4                      2                4            2
# ...                  ...              ...          ...
# 129875                 4                4            4
# 129876                 3                1            2
# 129877                 4                2            3
# 129878                 3                2            1
# 129879                 5                3            3
#
#         Departure Delay in Minutes  Arrival Delay in Minutes
# 0                                0                       0.0
# 1                              310                     305.0
# 2                                0                       0.0
# 3                                0                       0.0
# 4                                0                       0.0
# ...                            ...                       ...
# 129875                           0                       0.0
# 129876                         174                     172.0
# 129877                         155                     163.0
# 129878                         193                     205.0
# 129879                         185                     186.0
#
# [129880 rows x 18 columns]

# %% [markdown]
# # Missing Observation Analysis
#
# We saw on dataset.head() that some features contain 0, it doesn't make sense here and this indicates missing value Below we replace 0 value by NaN:

# %%
dataset_final=dataset

# %%
# Now, we can look at where are missing values
dataset.isnull().sum()
# Out:
# satisfaction                           0
# Customer Type                          0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %%
# Replacing NaN with mean values
dataset_final["Arrival Delay in Minutes"].fillna(dataset["Arrival Delay in Minutes"].mean(), inplace = True)

# %%
# new dataset with replaced values
dataset_final.isnull().sum()
# Out:
# satisfaction                         0
# Customer Type                        0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
# Statistical summary
dataset_final.describe().T
# Out:
#                                       count         mean          std   min  \
# Flight Distance                    129880.0  1981.409055  1027.115606  50.0
# Seat comfort                       129880.0     2.838597     1.392983   0.0
# Departure/Arrival time convenient  129880.0     2.990645     1.527224   0.0
# Food and drink                     129880.0     2.851994     1.443729   0.0
# Inflight wifi service              129880.0     3.249130     1.318818   0.0
# Inflight entertainment             129880.0     3.383477     1.346059   0.0
# Online support                     129880.0     3.519703     1.306511   0.0
# Ease of Online booking             129880.0     3.472105     1.305560   0.0
# On-board service                   129880.0     3.465075     1.270836   0.0
# Leg room service                   129880.0     3.485902     1.292226   0.0
# Baggage handling                   129880.0     3.695673     1.156483   1.0
# Checkin service                    129880.0     3.340807     1.260582   0.0
# Cleanliness                        129880.0     3.705759     1.151774   0.0
# Departure Delay in Minutes         129880.0    14.713713    38.071126   0.0
# Arrival Delay in Minutes           129880.0    15.091129    38.407410   0.0
#
#                                       25%     50%     75%     max
# Flight Distance                    1359.0  1925.0  2544.0  6951.0
# Seat comfort                          2.0     3.0     4.0     5.0
# Departure/Arrival time convenient     2.0     3.0     4.0     5.0
# Food and drink                        2.0     3.0     4.0     5.0
# Inflight wifi service                 2.0     3.0     4.0     5.0
# Inflight entertainment                2.0     4.0     4.0     5.0
# Online support                        3.0     4.0     5.0     5.0
# Ease of Online booking                2.0     4.0     5.0     5.0
# On-board service                      3.0     4.0     4.0     5.0
# Leg room service                      2.0     4.0     5.0     5.0
# Baggage handling                      3.0     4.0     5.0     5.0
# Checkin service                       3.0     3.0     4.0     5.0
# Cleanliness                           3.0     4.0     5.0     5.0
# Departure Delay in Minutes            0.0     0.0    12.0  1592.0
# Arrival Delay in Minutes              0.0     0.0    13.0  1584.0

# %%
dataset_final.columns = dataset_final.columns.str.replace(' ', '')
dataset_final.head(-1)
# Out:
#         satisfaction       CustomerType     Class  FlightDistance  \
# 0          satisfied     Loyal Customer       Eco             265
# 1          satisfied     Loyal Customer  Business            2464
# 2          satisfied     Loyal Customer       Eco            2138
# 3          satisfied     Loyal Customer       Eco             623
# 4          satisfied     Loyal Customer       Eco             354
# ...              ...                ...       ...             ...
# 129874     satisfied  disloyal Customer       Eco            2752
# 129875     satisfied  disloyal Customer       Eco            1731
# 129876  dissatisfied  disloyal Customer  Business            2087
# 129877  dissatisfied  disloyal Customer       Eco            2320
# 129878  dissatisfied  disloyal Customer       Eco            2450
#
#         Seatcomfort  Departure/Arrivaltimeconvenient  Foodanddrink  \
# 0                 0                                0             0
# 1                 0                                0             0
# 2                 0                                0             0
# 3                 0                                0             0
# 4                 0                                0             0
# ...             ...                              ...           ...
# 129874            5                                5             5
# 129875            5                                5             5
# 129876            2                                3             2
# 129877            3                                0             3
# 129878            3                                2             3
#
#         Inflightwifiservice  Inflightentertainment  Onlinesupport  \
# 0                         2                      4              2
# 1                         0                      2              2
# 2                         2                      0              2
# 3                         3                      4              3
# 4                         4                      3              4
# ...                     ...                    ...            ...
# 129874                    2                      5              2
# 129875                    2                      5              2
# 129876                    2                      1              1
# 129877                    3                      2              2
# 129878                    3                      2              2
#
#         EaseofOnlinebooking  On-boardservice  Legroomservice  Baggagehandling  \
# 0                         3                3               0                3
# 1                         3                4               4                4
# 2                         2                3               3                4
# 3                         1                1               0                1
# 4                         2                2               0                2
# ...                     ...              ...             ...              ...
# 129874                    2                3               5                3
# 129875                    2                3               3                4
# 129876                    3                2               3                3
# 129877                    4                4               3                4
# 129878                    3                3               2                3
#
#         Checkinservice  Cleanliness  DepartureDelayinMinutes  \
# 0                    5            3                        0
# 1                    2            3                      310
# 2                    4            4                        0
# 3                    4            1                        0
# 4                    4            2                        0
# ...                ...          ...                      ...
# 129874               5            4                        5
# 129875               4            4                        0
# 129876               1            2                      174
# 129877               2            3                      155
# 129878               2            1                      193
#
#         ArrivalDelayinMinutes
# 0                         0.0
# 1                       305.0
# 2                         0.0
# 3                         0.0
# 4                         0.0
# ...                       ...
# 129874                    0.0
# 129875                    0.0
# 129876                  172.0
# 129877                  163.0
# 129878                  205.0
#
# [129879 rows x 18 columns]

# %%
dataset_final.Class.unique()
# Out:
# array(['Eco', 'Business', 'Eco Plus'], dtype=object)

# %%
dataset_final.satisfaction[dataset_final.satisfaction == 'satisfied'] = 1
dataset_final.satisfaction[dataset_final.satisfaction == 'dissatisfied'] = 0

dataset_final.CustomerType[dataset_final.CustomerType == 'Loyal Customer'] = 1
dataset_final.CustomerType[dataset_final.CustomerType == 'disloyal Customer'] = 0


dataset_final.Class[dataset_final.Class == 'Eco'] = 0
dataset_final.Class[dataset_final.Class == 'Eco Plus'] = 1
dataset_final.Class[dataset_final.Class == 'Business'] = 2
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
dataset_final.Class.unique()
# Out:
# array([0, 2, 1], dtype=object)

# %%
dataset_final['satisfaction']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 129875    1
# 129876    0
# 129877    0
# 129878    0
# 129879    0
# Name: satisfaction, Length: 129880, dtype: object

# %%
dataset_final['satisfaction'] = pd.to_numeric(dataset_final['satisfaction'])
dataset_final['Class'] = pd.to_numeric(dataset_final['Class'])
dataset_final['CustomerType'] = pd.to_numeric(dataset_final['CustomerType'])

# %%
# Outcome countplot
import seaborn as sns
sns.countplot(x = 'satisfaction',data = dataset_final)
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='count'>

# %%
# Correlation matrix graph of the data set
f, ax = plt.subplots(figsize= [20,15])
sns.heatmap(dataset_final.corr(), annot=True, fmt=".2f", ax=ax, cmap = "magma" )
ax.set_title("Correlation Matrix", fontsize=20)
plt.show()

# %%
from sklearn.model_selection import train_test_split

y = dataset_final.iloc[:, 0]
X = dataset_final.iloc[:, 1:]
 
# split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.05, random_state=0)

# %%
# Checking dimensions
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("Y_train shape:", y_train.shape)
print("Y_test shape:", y_test.shape)
# Out:
# X_train shape: (123386, 17)
# X_test shape: (6494, 17)
# Y_train shape: (123386,)
# Y_test shape: (6494,)

# %%
print('X_train : ')
print(X_train.head())
print('')
print('X_test : ')
print(X_test.head())
print('')
print('y_train : ')
print(y_train.head())
print('')
print('y_test : ')
print(y_test.head())
# Out:
# X_train :
#         CustomerType  Class  FlightDistance  Seatcomfort  \
# 30033              1      0            2760            3
# 68875              1      1            1596            1
# 33892              1      0            1685            4
# 104314             1      2            2392            4
# 41215              0      0            2108            1
#
#         Departure/Arrivaltimeconvenient  Foodanddrink  Inflightwifiservice  \
# 30033                                 5             3                    1
# 68875                                 1             1                    1
# 33892                                 3             4                    1
# 104314                                1             1                    4
# 41215                                 0             1                    4
#
#         Inflightentertainment  Onlinesupport  EaseofOnlinebooking  \
# 30033                       3              4                    1
# 68875                       1              1                    1
# 33892                       4              1                    1
# 104314                      4              4                    4
# 41215                       1              4                    4
#
#         On-boardservice  Legroomservice  Baggagehandling  Checkinservice  \
# 30033                 3               2                5               5
# 68875                 3               2                4               1
# 33892                 2               2                2               1
# 104314                2               4                3               4
# 41215                 3               4                5               3
#
#         Cleanliness  DepartureDelayinMinutes  ArrivalDelayinMinutes
# 30033             1                       10                    0.0
# 68875             4                        0                    0.0
# 33892             5                        0                    0.0
# 104314            3                        0                   13.0
# 41215             5                        2                    0.0
#
# X_test :
#         CustomerType  Class  FlightDistance  Seatcomfort  \
# 125669             1      1            1216            5
# 90648              1      2             868            4
# 45322              0      2            1341            2
# 64084              1      2             269            0
# 71595              1      2            3458            2
#
#         Departure/Arrivaltimeconvenient  Foodanddrink  Inflightwifiservice  \
# 125669                                3             3                    5
# 90648                                 4             4                    2
# 45322                                 1             1                    4
# 64084                                 0             0                    4
# 71595                                 1             1                    1
#
#         Inflightentertainment  Onlinesupport  EaseofOnlinebooking  \
# 125669                      5              5                    5
# 90648                       5              5                    4
# 45322                       1              4                    4
# 64084                       5              4                    4
# 71595                       2              2                    2
#
#         On-boardservice  Legroomservice  Baggagehandling  Checkinservice  \
# 125669                3               5                1               2
# 90648                 4               4                4               2
# 45322                 5               5                5               5
# 64084                 4               4                4               3
# 71595                 2               2                2               1
#
#         Cleanliness  DepartureDelayinMinutes  ArrivalDelayinMinutes
# 125669            3                        0                   11.0
# 90648             4                        0                    0.0
# 45322             5                        0                    0.0
# 64084             4                       20                   18.0
# 71595             2                        0                    0.0
#
# y_train :
# 30033     0
# 68875     0
# 33892     0
# 104314    0
# 41215     0
# Name: satisfaction, dtype: int64
#
# y_test :
# 125669    1
# 90648     1
# 45322     0
# 64084     1
# 71595     0
# Name: satisfaction, dtype: int64

# %%
X_train.head()
# Out:
#         CustomerType  Class  FlightDistance  Seatcomfort  \
# 30033              1      0            2760            3
# 68875              1      1            1596            1
# 33892              1      0            1685            4
# 104314             1      2            2392            4
# 41215              0      0            2108            1
#
#         Departure/Arrivaltimeconvenient  Foodanddrink  Inflightwifiservice  \
# 30033                                 5             3                    1
# 68875                                 1             1                    1
# 33892                                 3             4                    1
# 104314                                1             1                    4
# 41215                                 0             1                    4
#
#         Inflightentertainment  Onlinesupport  EaseofOnlinebooking  \
# 30033                       3              4                    1
# 68875                       1              1                    1
# 33892                       4              1                    1
# 104314                      4              4                    4
# 41215                       1              4                    4
#
#         On-boardservice  Legroomservice  Baggagehandling  Checkinservice  \
# 30033                 3               2                5               5
# 68875                 3               2                4               1
# 33892                 2               2                2               1
# 104314                2               4                3               4
# 41215                 3               4                5               3
#
#         Cleanliness  DepartureDelayinMinutes  ArrivalDelayinMinutes
# 30033             1                       10                    0.0
# 68875             4                        0                    0.0
# 33892             5                        0                    0.0
# 104314            3                        0                   13.0
# 41215             5                        2                    0.0

# %% [markdown]
# # Data Visualization
# #

# %%
sns.heatmap(dataset_final.corr())
plt.show()

# %%
# The distribution of the outcome variable in the data was examined and visualized.
f,ax=plt.subplots(1,2,figsize=(18,8))
dataset_final['satisfaction'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
sns.countplot('satisfaction',data=dataset_final)
ax[1].set_title('satisfaction')
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Learning Algorithm

# %% [markdown]
# ### **KNN Algorithm**

# %%
scores_dict = {}

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123386 entries, 30033 to 68268
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   CustomerType                     123386 non-null  int64
#  1   Class                            123386 non-null  int64
#  2   FlightDistance                   123386 non-null  int64
#  3   Seatcomfort                      123386 non-null  int64
#  4   Departure/Arrivaltimeconvenient  123386 non-null  int64
#  5   Foodanddrink                     123386 non-null  int64
#  6   Inflightwifiservice              123386 non-null  int64
#  7   Inflightentertainment            123386 non-null  int64
#  8   Onlinesupport                    123386 non-null  int64
#  9   EaseofOnlinebooking              123386 non-null  int64
#  10  On-boardservice                  123386 non-null  int64
#  11  Legroomservice                   123386 non-null  int64
#  12  Baggagehandling                  123386 non-null  int64
#  13  Checkinservice                   123386 non-null  int64
#  14  Cleanliness                      123386 non-null  int64
#  15  DepartureDelayinMinutes          123386 non-null  int64
#  16  ArrivalDelayinMinutes            123386 non-null  float64
# dtypes: float64(1), int64(16)
# memory usage: 16.9 MB

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_scores = []
n_value = []
for i in range (1,17,2):
    model_knn = KNeighborsClassifier(n_neighbors =i).fit(X_train, y_train)
    knn_scores.append(model_knn.score(X_test,y_test))
    n_value.append(i)

# %%
knn_scores
# Out:
# [0.7365260240221743,
#  0.743455497382199,
#  0.7488450877733293,
#  0.7573144441022482,
#  0.7551586079457961,
#  0.754388666461349,
#  0.7511549122266707,
#  0.7542346781644595]

# %%
n_value
# Out:
# [1, 3, 5, 7, 9, 11, 13, 15]

# %%
knn_scores = np.array(knn_scores)
n_value = np.array(n_value)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_xlabel("score")
ax.set_ylabel("Number of Neighbours")
ax.bar(n_value,knn_scores)
plt.show()

# %% [markdown]
# ### **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

model_log = LogisticRegression().fit(X_train, y_train)

model_log.score(X_test,y_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 0.754388666461349

# %% [markdown]
# ### **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier


model_rfc = RandomForestClassifier().fit(X_train, y_train)
model_rfc.score(X_test,y_test)
# Out:
# 0.9501077918078226

# %% [markdown]
# **Accuracy**

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from numpy import mean
from numpy import std


cv = KFold(n_splits=10, random_state=1, shuffle=True)
scores = cross_val_score(model_knn, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
scores_dict['KNeighborsClassifier'] = mean(scores)*100
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.749 (0.002)

# %%
cv = KFold(n_splits=10, random_state=1, shuffle=True)
scores = cross_val_score(model_log, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
scores_dict['LogisiticRegression'] = mean(scores)*100
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.758 (0.004)

# %%
cv = KFold(n_splits=10, random_state=1, shuffle=True)
scores = cross_val_score(model_rfc, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
scores_dict['RandomForest'] = mean(scores)*100
print('Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Accuracy: 0.948 (0.001)

# %%
with sns.color_palette('muted'):
  algo_name = list(scores_dict.keys())
  scoress = list(scores_dict.values())

  sns.set(rc={'figure.figsize':(13,7)})
  plt.xlabel("ML Algorithms")
  plt.ylabel("Accuracy score")

  sns.barplot(algo_name,scoress)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ***Conclusion: Among the 3 algorithms , RandomForest Algorithm has the highest accuracy in classification***
